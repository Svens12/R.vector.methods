# %%
x<-c(10,45,30,50)

# %%
length(x)
# Out:
# [1] 4

# %%
sum(x)
# Out:
# [1] 135

# %%
prod(x)
# Out:
# [1] 675000

# %%
rev(x)
# Out:
# [1] 50 30 45 10

# %%
sort(x)
# Out:
# [1] 10 30 45 50

# %%
sort(x,decreasing=TRUE)
# Out:
# [1] 50 45 30 10

# %%
x<-c(10,45,30,50)
y<-c(5,1,4,3)
x %*% y
# Out:
#      [,1]
# [1,] 365

# %%
crossprod(x,y)
# Out:
#      [,1]
# [1,] 365

# %%
x %o% y
# Out:
#      [,1] [,2] [,3] [,4]
# [1,]  50  10    40   30
# [2,] 225  45   180  135
# [3,] 150  30   120   90
# [4,] 250  50   200  150

# %%
tcrossprod(x,y)
# Out:
#      [,1] [,2] [,3] [,4]
# [1,]  50  10    40   30
# [2,] 225  45   180  135
# [3,] 150  30   120   90
# [4,] 250  50   200  150
